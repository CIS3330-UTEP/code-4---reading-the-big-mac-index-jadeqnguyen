# %% [markdown]
# # My First Notebook

# %% [markdown]
# Below I will import all the dependencies for my project.

# %%
import pandas as pd

# %% [markdown]
# Now I will read my csv file containing the data from big macs.

# %%
df = pd.read_csv("big-mac-full-index.csv")

# %% [markdown]
# Below I will execute some neat things I have learned so far.

# %%
df
# Out:
#             date iso_a3 currency_code           name  local_price  \
# 0     2000-04-01    ARG           ARS      Argentina         2.50
# 1     2000-04-01    AUS           AUD      Australia         2.59
# 2     2000-04-01    BRA           BRL         Brazil         2.95
# 3     2000-04-01    CAN           CAD         Canada         2.85
# 4     2000-04-01    CHE           CHF    Switzerland         5.90
# ...          ...    ...           ...            ...          ...
# 1626  2022-07-01    URY           UYU        Uruguay       255.00
# 1627  2022-07-01    USA           USD  United States         5.15
# 1628  2022-07-01    VEN           VES      Venezuela        10.00
# 1629  2022-07-01    VNM           VND        Vietnam     69000.00
# 1630  2022-07-01    ZAF           ZAR   South Africa        39.90
#
#         dollar_ex  dollar_price  USD_raw  EUR_raw  GBP_raw  JPY_raw  CNY_raw  \
# 0         1.00000      2.500000  0.11607  0.05007 -0.16722 -0.09864  1.09091
# ...

# %%
df.columns
# Out:
# Index(['date', 'iso_a3', 'currency_code', 'name', 'local_price', 'dollar_ex',
#        'dollar_price', 'USD_raw', 'EUR_raw', 'GBP_raw', 'JPY_raw', 'CNY_raw',
#        'GDP_bigmac', 'adj_price', 'USD_adjusted', 'EUR_adjusted',
#        'GBP_adjusted', 'JPY_adjusted', 'CNY_adjusted'],
#       dtype='object')

# %%
df_arg = df.query('iso_a3 == "ARG"')

# %%
df_arg
# Out:
#             date iso_a3 currency_code       name  local_price  dollar_ex  \
# 0     2000-04-01    ARG           ARS  Argentina         2.50    1.00000
# 28    2001-04-01    ARG           ARS  Argentina         2.50    1.00000
# 56    2002-04-01    ARG           ARS  Argentina         2.50    3.13000
# 89    2003-04-01    ARG           ARS  Argentina         4.10    2.88000
# 121   2004-05-01    ARG           ARS  Argentina         4.36    2.95000
# 162   2005-06-01    ARG           ARS  Argentina         4.75    2.89700
# 202   2006-01-01    ARG           ARS  Argentina         4.75    3.06380
# 235   2006-05-01    ARG           ARS  Argentina         7.00    3.05650
# 276   2007-01-01    ARG           ARS  Argentina         8.25    3.08875
# 317   2007-06-01    ARG           ARS  Argentina         8.25    3.09150
# 358   2008-06-01    ARG           ARS  Argentina        11.00    3.01950
# 398   2009-07-01    ARG           ARS  Argentina        11.50    3.81125
# ...

# %%
country_code = "MEX"

# %%
df_country = df.query("")
